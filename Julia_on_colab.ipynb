# %% [markdown]
# ## Mount Google Drive first
# > Suppose we `!git clone https://github.com/Dsantra92/Julia-on-Colab.git` under `/content/drive/MyDrive/git/` which corresponds to our own Google Drive's `rootdir/git/`.
# Then we can double click `rootdir/git/Julia-on-Colab/Julia_on_colab.ipynb` in our Google Drive in Chrome to open it in colab.
# `Colab Pro` will be very convenient with providing terminal interface directly.
#
# Mount need to work under runtime "Python 3", but after change runtime back to "Python 3", ipynb's metadata will change back to Python 3, so need to change to "Julia 1.6" again.
# SO change runtime to "Python 3" and refresh this page to make runtime change work, then run the next cell.

# %%
# mount google drive first
from google.colab import drive
drive.mount('/content/drive')

# change ipynb's metadata
ipynb_path = "/content/drive/MyDrive/git/Julia-on-Colab/Julia_on_colab.ipynb" # !!! change to your own ipynb_path
import json
# open
a_file = open(ipynb_path, "r")
json_object = json.load(a_file)
a_file.close()
print(json_object['metadata']['kernelspec']['name'])
print(json_object['metadata']['kernelspec']['display_name'])
# change
json_object['metadata']['kernelspec']['name'] = 'julia-1.6' # /root/.local/share/jupyter/kernels/julia-1.6/
json_object['metadata']['kernelspec']['display_name'] = 'Julia 1.6'
a_file = open(ipynb_path, "w")
json.dump(json_object, a_file)
a_file.close()
# test
a_file = open(ipynb_path, "r")
json_object = json.load(a_file)
a_file.close()
print(json_object['metadata']['kernelspec']['name'])
print(json_object['metadata']['kernelspec']['display_name'])

# !!! do not ctrl+s, just refresh this page directly, and then chose runtime "Julia 1.6" and save. 
# now ipynb use runtime "Julia 1.6" again, do the next steps.

# %% [markdown]
# ## Install Julia

# %%
# Installation cell
# %%capture
# %%shell
# install Julia
if ! command -v julia 3>&1 > /dev/null
then
    wget -q 'https://julialang-s3.julialang.org/bin/linux/x64/1.6/julia-1.6.1-linux-x86_64.tar.gz' \
        -O /tmp/julia.tar.gz
    tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
    rm /tmp/julia.tar.gz
fi
# install IJulia
julia -e 'using Pkg; pkg"add IJulia; precompile;"'
echo 'Done'

# %% [markdown]
# After you run the first cell (the the cell directly above this text), go to Colab's menu bar and select **Edit** and select **Notebook settings** from the drop down. Select *Julia 1.6* in Runtime type. You can also select your prefered harwdware acceleration (defaults to GPU).
#
# <br/>You should see something like this:
#
# > ![Colab Img](https://raw.githubusercontent.com/Dsantra92/Julia-on-Colab/master/misc/julia_menu.png)
#
# <br/>Click on SAVE
# <br/>**We are ready to get going**

# %%
VERSION
# Out:
# v"1.6.1"

# %% [markdown]
# **The next three cells are for GPU benchmarking. If you are using this notebook for the first time and have GPU enabled, you can give it a try.**

# %% [markdown]
# ### Optional GPU Experiments

# %%
using Pkg
Pkg.add(["BenchmarkTools", "CUDA"])
using BenchmarkTools, CUDA

if has_cuda_gpu()
  print("The GPU device is:", CUDA.device())
end

# %%
mcpu = rand(2^10, 2^10)
@benchmark mcpu*mcpu

# %%
println("The CuArrray operation should take around 0.5 ms(excluding CUDA downloading time which is a one time process), and should be much faster. If so, the GPU is working.")
mgpu = cu(mcpu)
@benchmark CUDA.@sync mgpu*mgpu
